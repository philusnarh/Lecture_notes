# %% [markdown]
# ### This simple function open .csv file with bad separation

# %%
import pandas as pd

# %%
gfile="tahmo_Benso_SHSdata.csv"
data = pd.read_csv(filepath_or_buffer='%s' %gfile,names = list(range(0,3)))
data
# Out:
#                                                                              0  \
# site    name                              day              total rainfall (mm)
# TA00002 Benso SHS                         2018-05-15                         0
#                                           2018-05-16                      3.11
#                                           2018-05-17                      3.54
#                                           2018-05-18                      0.04
#                                           2018-05-19                      8.37
# TA00003 Prestea SHTS                      2018-05-15                      0.79
#                                           2018-05-16                      0.25
#                                           2018-05-17                     10.13
#                                           2018-05-18                      5.58
#                                           2018-05-19                      4.75
# ...
